# %% [markdown]
# # Cosine Similarity
# _Author: Raffy Santayana_
#
# The purpose of this notebook is to explore the effectiveness of evaluating how well LLMs are at summarizing SEC reports and how to interpret different cosine similarity metrics depending on the transformer used.
#
# __Transformers__
# 1. TF-IDF
# 2. Word2Vec (Study CBOW and Skip-Gram) https://www.geeksforgeeks.org/continuous-bag-of-words-cbow-in-nlp/
# 3. BERT (Look into other variations of BERT such as ALBERT, DistiliBERT, ELECTRA, and RoBERTa) https://huggingface.co/docs/transformers/model_doc/bert
#
# First, let us get an article to be MapReduced to a smaller token size that can be submitted to GPT4.

# %%
import pandas as pd
import requests

# %%
df = pd.read_csv('../data/all_10qs.csv').drop()
# Out:
# C:\Users\Raffy\AppData\Local\Temp\ipykernel_10384\722070581.py:1: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('../data/all_10qs.csv')

# %%
df.head()
# Out:
#    Unnamed: 0 ticker exchange      accession_number filing_date report_date  \
# 0           0   CVCY   Nasdaq  0001628280-24-023222  2024-05-14  2024-03-31
# 1           1   CVCY   Nasdaq  0001127371-23-000152  2023-11-02  2023-09-30
# 2           2   CVCY   Nasdaq  0001127371-23-000128  2023-08-03  2023-06-30
# 3           3   CVCY   Nasdaq  0001127371-23-000072  2023-05-15  2023-03-31
# 4           4   CVCY   Nasdaq  0001127371-22-000167  2022-11-02  2022-09-30
#
#         acceptance_datetime   act  form file_number  ...      size  \
# 0  2024-05-14T16:19:29.000Z  34.0  10-Q   000-31977  ...  12967977
# 1  2023-11-02T14:38:44.000Z  34.0  10-Q   000-31977  ...  12864003
# 2  2023-08-03T16:56:00.000Z  34.0  10-Q   000-31977  ...  12459205
# 3  2023-05-12T18:46:16.000Z  34.0  10-Q   000-31977  ...  12111169
# 4  2022-11-02T13:29:11.000Z  34.0  10-Q   000-31977  ...  13954236
#
#     primary_document  is_XBRL is_inline_XBRL  primary_doc_description  \
# ...
